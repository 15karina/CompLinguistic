# %% [markdown]
# 1. вводим словарь соответствий по частям речи: 'слово на старославянском': 'слово на современном русском языке':
#
#    1.1. для существительных
#
#    1.2. для глаголов
#
#    1.3. для прилагательных
#
#    1.4. для местоимений
#
#    1.5. для наречий
#
#    1.6. для числительных
#
# 2. принимаем текст на ввод на старославянском языке
#
# 3. токенизация текста
#
# 4. частеречная разметка
#
# 5. для существительных, местоимений, прилагательных и числительных определяем род, число, падеж
#
# 6. для глаголов определяем время, лицо, число
#
# 7. генерация слов
#
# 8. добавление заглавных букв
#
# 9. вывод на экран перевода текста на русский язык

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import re

# %%
file_path = 'rainbow_valley.txt'

# %%
with open(file_path, 'r', encoding='utf-8') as file:
  text = file.read()

# %%
text = text.lower()
text[500:1000]
# Out:
# 'marshall elliott for thirteen\nyears, but even yet more people referred to her as miss cornelia than\nas mrs. elliott. the old name was dear to her old friends, only one of\nthem contemptuously dropped it. susan baker, the gray and grim and\nfaithful handmaiden of the blythe family at ingleside, never lost an\nopportunity of calling her “mrs. marshall elliott,” with the most\nkilling and pointed emphasis, as if to say “you wanted to be mrs. and\nmrs. you shall be with a vengeance as far as i am concern'

# %%
text = re.sub(r'[^a-z\s\.\?!]', '', text)
text[500:1000]
# Out:
# 'lliott for thirteen\nyears but even yet more people referred to her as miss cornelia than\nas mrs. elliott. the old name was dear to her old friends only one of\nthem contemptuously dropped it. susan baker the gray and grim and\nfaithful handmaiden of the blythe family at ingleside never lost an\nopportunity of calling her mrs. marshall elliott with the most\nkilling and pointed emphasis as if to say you wanted to be mrs. and\nmrs. you shall be with a vengeance as far as i am concerned.\n\nmiss cornelia '

# %%
sentences = re.split(r'[\.\?!]', text)
sentences[1:3]
# Out:
# ['\nhome again\n\n\nit was a clear applegreen evening in may and four winds harbour was\nmirroring back the clouds of the golden west between its softly dark\nshores',
#  ' the sea moaned eerily on the sandbar sorrowful even in\nspring but a sly jovial wind came piping down the red harbour road\nalong which miss cornelias comfortable matronly figure was making its\nway towards the village of glen st']

# %%
sentences = [sentence.split() for sentence in sentences if sentence]
sentences[3]
# Out:
# ['mary']

# %%
co_occurrence = defaultdict(lambda: defaultdict(int))

# %%
def update_co_occurrence(sentence, window_size=1):
    words = [""] + sentence + [""]
    for i, word in enumerate(words):
        for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
            if i != j:
                co_occurrence[word][words[j]] += 1

for sentence in sentences:
    update_co_occurrence(sentence)

co_occurrence['aint']
# Out:
# defaultdict(int,
#             {'there': 4,
#              'a': 4,
#              '': 2,
#              'it': 5,
#              'una': 1,
#              'them': 2,
#              'i': 9,
#              'going': 2,
#              'oh': 1,
#              'house': 1,
#              'hardly': 1,
#              'got': 1,
#              'like': 1,
#              'say': 1,
#              'proudbut': 1,
#              'licked': 1,
#              'fond': 1,
#              'no': 1,
#              'any': 1,
#              'ladylike': 1,
#              'that': 2,
#              'never': 1,
#              'said': 1,
#              'she': 1,
#              'lida': 1,
#              'this': 1,
#              'you': 1,
#              'true': 1})

# %%
tokens = list(co_occurrence.keys())
tokens[10:20]
# Out:
# ['clear',
#  'applegreen',
#  'evening',
#  'in',
#  'may',
#  'and',
#  'four',
#  'winds',
#  'harbour',
#  'mirroring']

# %%
co_occurrence_df = pd.DataFrame(co_occurrence).fillna(0).astype(int).reindex(tokens, columns=tokens, fill_value=0)
co_occurrence_df
# Out:
#                        rainbow  valley  chapter    i  home  again   it  was  \
#                     2        3      33       35  571    32     51  403   21
# rainbow             3        0      85        0    0     0      0    1    0
# valley             33       85       0        1    0     0      1    0    6
# chapter            35        0       1        0    1     0      0    0    0
# i                 571        0       0        1    0     0      0    4   67
# ...               ...      ...     ...      ...  ...   ...    ...  ...  ...
# pipesand            0        0       0        0    0     0      0    0    0
# followjem           0        0       0        0    0     0      0    0    0
# iround              0        0       0        0    0     0      0    0    0
# listenlistencant    1        0       0        0    0     0      0    0    0
# pretending          0        0       0        0    0     0      0    0    0
#
#                    a  ...  prospect  astar  pageant  cloak  pipeshe  pipesand  \
#                   55  ...         0      0        0      0        0         0
# rainbow            0  ...         0      0        0      0        0         0
# valley             1  ...         0      0        0      0        0         0
# chapter            0  ...         0      0        0      0        0         0
# i                  0  ...         0      0        0      0        0         0
# ...               ..  ...       ...    ...      ...    ...      ...       ...
# pipesand           0  ...         0      0        0      0        1         0
# followjem          0  ...         0      0        0      0        0         0
# iround             0  ...         0      0        0      0        0         0
# listenlistencant   0  ...         0      0        0      0        0         0
# pretending         0  ...         0      0        0      0        0         0
#
#                   followjem  iround  listenlistencant  pretending
#                           0       0                 1           0
# rainbow                   0       0                 0           0
# valley                    0       0                 0           0
# chapter                   0       0                 0           0
# i                         0       0                 0           0
# ...                     ...     ...               ...         ...
# pipesand                  0       0                 0           0
# followjem                 0       0                 0           0
# iround                    0       0                 0           0
# listenlistencant          0       0                 0           0
# pretending                0       0                 0           0
#
# [7600 rows x 7600 columns]
